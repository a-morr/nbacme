# %%
import numpy as np
import pandas as pd
from Machine_Learning.elo import *
import datetime as dt
from Machine_Learning import kristaps
reload(kristaps)
from matplotlib import pyplot as plt

# %matplotlib inline

# %% [markdown]
# # Elo Rating Over Time

# %%
k = kristaps.Kristaps()

# %%
k.train_all(pd.read_csv('data/all_games.csv'),write = 0)

# %% [markdown]
# See how the top three teams have compared over the past thousand games

# %%
k.plot_Elo(['Cavaliers', 'Warriors', 'Spurs'], games=1000, window=45, order=5)

# %% [markdown]
# Same plot, just the last hundred games

# %%
k.plot_Elo(['Cavaliers', 'Warriors', 'Spurs'], 100, window=25, order=5)
