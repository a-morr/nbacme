# %%
import numpy as np
import pandas as pd
import kristaps
reload(kristaps)
# Out:
# <module 'kristaps' from 'kristaps.pyc'>

# %%
k = kristaps.Kristaps()

# %%
k.train(pd.read_csv('../data/historical_data.csv'))

# %%
k.simulate_seasons()
# Out:
#     Projected L  Projected W          elo       fran_id
# 28         15.0         67.0  1785.934160      Warriors
# 23         21.0         61.0  1681.546687         Spurs
# 2          24.0         58.0  1677.473813     Cavaliers
# 4          30.0         52.0  1673.022950      Clippers
# 21         25.0         57.0  1669.297610       Rockets
# 5          34.0         48.0  1637.208130     Grizzlies
# 6          37.0         45.0  1588.468632         Hawks
# 25         36.0         46.0  1576.319199       Thunder
# 14         45.0         37.0  1569.643485     Mavericks
# 1          39.0         43.0  1554.396979         Bulls
# 27         43.0         39.0  1542.691199  Trailblazers
# 29         33.0         49.0  1538.747786       Wizards
# 18         47.0         35.0  1533.474805      Pelicans
# 17         38.0         44.0  1511.299955        Pacers
# 9          35.0         47.0  1509.712613          Jazz
# 15         61.0         21.0  1499.818817          Nets
# ...
