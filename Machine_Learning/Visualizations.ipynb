# %%
import numpy as np
import pandas as pd
from elo import *
import datetime as dt
import kristaps
reload(kristaps)
from matplotlib import pyplot as plt
# %matplotlib inline

# %% [markdown]
# # Elo Rating Over Time

# %%
k = kristaps.Kristaps()

# %%
k.train_all(pd.read_csv('../data/historical_data.csv'),write = 0)

# %%
k.plot_Elo(['Warriors','Nets'],games=80)
